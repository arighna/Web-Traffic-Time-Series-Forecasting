# %%
import os
import sys
import pandas as pd
import numpy as np
import math

import matplotlib.pylab as plt
# %matplotlib inline

# %%
# mypath = 'C:/Users/MyNewPC/Documents/Study/Projects/Wiki/Data/'
# print (os.getcwd())

# %%
# print ('hello')
# wiki_data  = pd.read_csv(os.getcwd()+'train_1.csv')
# print (wiki_data.shape)
# wiki_data.to_pickle(os.getcwd()+'wiki_data')

# %%
# key_data  = pd.read_csv(os.getcwd()+'key_1.csv')
# print (key_data.shape)
# key_data.to_pickle(os.getcwd()+'key_data')

# %%
# wiki_data = pd.read_pickle(os.getcwd()+'/../Data/'+'wiki_data')
# key_data = pd.read_pickle(os.getcwd()+'/../Data/'+'key_data')
# print (wiki_data.shape)
# print (key_data.shape)
# print (wiki_data.columns)
# print (key_data.columns)

# %%
# print (wiki_data.iloc[58456,:1])
# print (key_data.iloc[58456,:])

# %%
# agent = []
# access = []
# project = []
# page = []
# for i in range(wiki_data.shape[0]):
#     agent.append( wiki_data.loc[i,'Page'].split('_')[-1] )
#     access.append( wiki_data.loc[i,'Page'].split('_')[-2] )
#     project.append( wiki_data.loc[i,'Page'].split('_')[-3] )
#     page.append( '_'.join(wiki_data.loc[i,'Page'].split('_')[:-3]) )

    
# wiki_data['page'], wiki_data['project'], wiki_data['access'], wiki_data['agent'] = page, project, access, agent
# wiki_data.drop('Page',axis=1,inplace=True)
# # print (wiki_data.head())
# wiki_data.to_pickle(os.getcwd()+'/../Data/'+'wiki_data_split')

# %%
wiki_data = pd.read_pickle(os.getcwd()+'/../Data/'+'wiki_data_split')

# %%
# pd.merge(wiki_data, key_data, how='inner', left_on='page', right_on='Page')

# %%
# wiki_data.iloc[2,:-4].plot()

# %%
# print (wiki_data.shape, len(wiki_data['page'].unique()))
# print (wiki_data.shape, len(wiki_data['project'].unique()))
# print (wiki_data.shape, len(wiki_data['access'].unique()))
# print (wiki_data.shape, len(wiki_data['agent'].unique()))

# print (list(wiki_data.columns[-4:]))

# for col in wiki_data.columns[-3:]:
#     print (wiki_data.groupby(col).size())

# %%
# grouped = wiki_data.groupby(list(wiki_data.columns[-3:])).size().reset_index()

# for col in list(wiki_data.columns[-3:]):
#     grouped = wiki_data.groupby(col).size().reset_index()
#     print (grouped.sort_values(col, ascending=False))
#     grouped.plot(kind='bar')
# Out:
#                  project      0
# 8       zh.wikipedia.org  17229
# 7      www.mediawiki.org   7300
# 6       ru.wikipedia.org  15022
# 5       ja.wikipedia.org  20431
# 4       fr.wikipedia.org  17802
# 3       es.wikipedia.org  14069
# 2       en.wikipedia.org  24108
# 1       de.wikipedia.org  18547
# 0  commons.wikimedia.org  10555
#        access      0
# 2  mobile-web  35939
# 1     desktop  34809
# 0  all-access  74315
#         agent       0
# 1      spider   34913
# 0  all-agents  110150

# %%
# for col in list(wiki_data.columns[-3:]):
#     grouped = wiki_data.groupby(col).sum()
#     grouped = wiki_data.groupby(col).mean()
#     # print (grouped)
#     for i in range(grouped.shape[0]):
#         ax = grouped.iloc[i,:-3].plot(legend = True)
#     fig = ax.get_figure()
#     plt.show(block=False)
#     plt.close(fig)

# %%
# test_series = wiki_data.iloc[5,:-4]
# test_series.plot()


# from scipy.stats import mstats

# low = .05
# high = .95
# quant_df = test_series.quantile([low, high])
# print (quant_df)

# transformed_test_series = pd.Series(mstats.winsorize(test_series, limits=[0.00, 0.01])) 
# transformed_test_series.plot()
# Out:
# 0.05        5
# 0.95    32.55
# Name: 5, dtype: object

# %%
# test_series = wiki_data.iloc[5,:-4]
# test_series.plot()

# score = test_series.mean() + 3*test_series.std()
# pd.DataFrame([score if x > score else x for x in test_series],index=test_series.index)
# transformed_test_series = pd.Series([score if x > score else x for x in test_series],index=test_series.index)
# transformed_test_series.plot()

# %%
# rolling = pd.rolling_mean(test_series, 7)
# test_series.plot(x_compat=True, style='r--')
# rolling.plot(style='b')

# %%
# test_series.index = pd.to_datetime(test_series.index)
# test_series = test_series.astype(float)
# test_series.groupby(test_series.index.month).mean()
# test_series.groupby(test_series.index.week).mean()
# test_series.groupby(test_series.index.day).mean()
# test_series.groupby(test_series.index.weekday).mean()

# %%
# grouped = test_series.groupby(test_series.index.weekday)
# ts_df = pd.DataFrame(list(test_series),columns = ['views'], index = test_series.index)


# ax = ts_df.boxplot(column=['views'], by= test_series.index.month )
# # ts_df.boxplot(column=['views'], by= test_series.index.week )
# # ts_df.boxplot(column=['views'], by= test_series.index.day )
# # ax = ts_df.boxplot(column=['views'], by= test_series.index.weekday )
# ax.set_ylim([0,30])

# %%
# from statsmodels.tsa.stattools import adfuller
# def test_stationarity(timeseries):
    
#     #Determing rolling statistics
#     rolmean = pd.rolling_mean(timeseries, window=12)
#     rolstd = pd.rolling_std(timeseries, window=12)

#     #Plot rolling statistics:
#     orig = plt.plot(timeseries, color='blue',label='Original')
#     mean = plt.plot(rolmean, color='red', label='Rolling Mean')
#     std = plt.plot(rolstd, color='black', label = 'Rolling Std')
#     plt.legend(loc='best')
#     plt.title('Rolling Mean & Standard Deviation')
#     plt.show(block=False)
    
#     #Perform Dickey-Fuller test:
#     print ('Results of Dickey-Fuller Test:')
#     dftest = adfuller(timeseries, autolag='AIC')
#     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#     for key,value in dftest[4].items():
#         dfoutput['Critical Value (%s)'%key] = value
#     print (dfoutput)
    
# test_stationarity(test_series)

# %%
# from statsmodels.tsa.seasonal import seasonal_decompose
# decomposition = seasonal_decompose(test_series)

# trend = decomposition.trend
# seasonal = decomposition.seasonal
# residual = decomposition.resid

# plt.subplot(411)
# plt.plot(test_series, label='Original')
# plt.legend(loc='best')
# plt.subplot(412)
# plt.plot(trend, label='Trend')
# plt.legend(loc='best')
# plt.subplot(413)
# plt.plot(seasonal,label='Seasonality')
# plt.legend(loc='best')
# plt.subplot(414)
# plt.plot(residual, label='Residuals')
# plt.legend(loc='best')
# plt.tight_layout()

# %%
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error


def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 200.0
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return np.nanmean(diff)

error = []

for i in range (wiki_data.shape[0]):
    test_series = wiki_data.iloc[i,:-4]
    score = test_series.mean() + 3*test_series.std()
    pd.DataFrame([score if x > score else x for x in test_series],index=test_series.index)
    transformed_test_series = pd.Series([score if x > score else x for x in test_series],index=test_series.index)

    X = transformed_test_series.values
    size = int(len(X) * 0.85)
    train, test = X[0:size], X[size:len(X)]
    history = [x for x in train]
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=(4,0,0))
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
    # 	print('predicted=%f, expected=%f' % (yhat, obs))

    error.append (smape( test, predictions ))


    
    
#     error = mean_squared_error(test, predictions)
#     print('Test MSE: %.3f' % error)
#     print (smape( test, predictions ))

#     # plot
#     pyplot.plot(test)
#     pyplot.plot(predictions, color='red')
#     pyplot.show()
# Out:
# Test MSE: 374.478
# 40.7933899341

# %%
print (error.mean())
    
with open(os.getcwd()+'/../Data/'+'error.csv','wb') as f:
    writer=csv.writer(f)
    writer.writerows(error)

# %%
# submission_data  = pd.read_csv(os.getcwd()+'/../Data/'+'sample_submission_1.csv')
# print (submission_data.shape)
# submission_data.to_pickle(os.getcwd()+'/../Data/'+'submission_data')
# Out:
# (8703780, 2)

# %%
# key_data = pd.read_pickle(os.getcwd()+'/../Data/'+'key_data')
# submission_data = pd.read_pickle(os.getcwd()+'/../Data/'+'submission_data')

# print (submission_data.shape, key_data.shape)

# submission_data = pd.merge(submission_data, key_data, how='left', left_on='Id', right_on='Id')

# submission_data.shape
# Out:
# (8703780, 2) (8703780, 2)
# (8703780, 3)

# %%
# dates = []
# agent = []
# access = []
# project = []
# page = []
# for i in range(submission_data.shape[0]):
#     dates.append( submission_data.loc[i,'Page'].split('_')[-1] )
#     agent.append( submission_data.loc[i,'Page'].split('_')[-2] )
#     access.append( submission_data.loc[i,'Page'].split('_')[-3] )
#     project.append( submission_data.loc[i,'Page'].split('_')[-4] )
#     page.append( '_'.join(submission_data.loc[i,'Page'].split('_')[:-4]) )


# submission_data['page'], submission_data['project'], submission_data['access'], submission_data['agent'], submission_data['date'] = page, project, access, agent, dates
# submission_data.drop('Page',axis=1,inplace=True)

# submission_data.to_pickle(os.getcwd()+'/../Data/'+'submission_data')

# %%
submission_data = pd.read_pickle(os.getcwd()+'/../Data/'+'submission_data')

print (submission_data.shape)

# %%
# grouped = submission_data.groupby(['page','project','access','agent'])
print (len(grouped))
print (wiki_data.shape)
# Out:
# 145063
# (145063, 554)

# %%
train_test = None
counter = 0

for key in list(grouped.groups.keys()):
    
    train = wiki_data [ (wiki_data['page'] == key[0]) & (wiki_data['project'] == key[1])  \
                       & (wiki_data['access'] == key[2]) & (wiki_data['agent'] == key[3]) ]\
                        .iloc[:,:].reset_index()
    
    series_info = train.iloc[:,-4:]
    train = train.iloc[:,:-4]
    
    if train.shape[0] == 0:
        print (key)
        continue
    
    test  = pd.DataFrame ([[0]*60], columns = grouped.get_group(key)['date']).reset_index()
    temp_train_test = pd.concat([ series_info, train, test ], axis = 1)
    
    if train_test is None:
        train_test = temp_train_test
    else:
        train_test = pd.concat([ train_test, temp_train_test ])
    
    
    if counter > 100:
        counter = 0
        print (train_test.shape[0])
    counter += 1
        

train_test.to_pickle(os.getcwd()+'/../Data/'+'train_test')
# Out:
# 102
# 203
# 304
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-c2fcb2cbf932> in <module>()
#       4 for key in list(grouped.groups.keys()):
#       5
# ----> 6     train = wiki_data [ (wiki_data['page'] == key[0]) & (wiki_data['project'] == key[1])                         & (wiki_data['access'] == key[2]) & (wiki_data['agent'] == key[3]) ]                        .iloc[:,:].reset_index()
#       7
#       8     series_info = train.iloc[:,-4:]
#
# C:\Users\MyNewPC\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
#     918             name = _maybe_match_name(self, other)
#     919             is_other_int_dtype = is_integer_dtype(other.dtype)
# --> 920             other = fill_int(other) if is_other_int_dtype else fill_bool(other)
#     921
#     922             filler = (fill_int if is_self_int_dtype and is_other_int_dtype
#
# ...

# %%
np.mean(train_test.iloc[1,-60:])
# Out:
# 0.0

# %%
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error


def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 200.0
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return np.nanmean(diff)



for i in range (train_test.shape[0]):
    
    mean         = np.mean(train_test.iloc[i,5:-60])  
    train_series = train_test.iloc[i,5:-60]
    train_series.fillna( value = mean , inplace = True )
    
    test_series  = train_test.iloc[i,-60: ]
    
    score = train_series.mean() + 3 * train_series.std()
    pd.DataFrame( [ score if x > score else x for x in train_series ], index = train_series.index )
    transformed_train_series = pd.Series([score if x > score else x for x in train_series],index=train_series.index)
    
    train = transformed_train_series.values
    test  = test_series.values
    
    history     = [x for x in train]
    predictions = list()
    
    for t in range(len(test)):
        model = ARIMA(history, order=(4,0,0))
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        train_test.iloc[i,-60+t] = yhat


train_test.to_pickle(os.getcwd()+'/../Data/'+'predicted')
# Out:
# C:\Users\MyNewPC\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\MyNewPC\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\MyNewPC\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\MyNewPC\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ...

# %%
print (submission_data.loc[1,])
train_test.iloc[1,:10]
# Out:
# Id             929ed2bf52b9
# Visits                    0
# page                  !vote
# project    en.wikipedia.org
# access           all-access
# agent            all-agents
# date             2017-01-02
# Name: 1, dtype: object
# page                     !vote
# project       en.wikipedia.org
# access              all-access
# agent                   spider
# index                    32275
# 2015-07-01                   0
# 2015-07-02                   0
# 2015-07-03                   1
# 2015-07-04                   2
# 2015-07-05                   0
# Name: 0, dtype: object

# %%
for i in range(submission_data.shape[0]):
    
    date = submission_data.iloc[i,6]
    submission_data.iloc[i,1] = train_test [ (train_test['page'] == submission_data.iloc[i,2]) \
                                            & (train_test['project'] == submission_data.iloc[i,3]) \
                                            & (train_test['access'] == submission_data.iloc[i,4]) \
                                            & (train_test['agent'] == submission_data.iloc[i,5])\
                                            ] [date].values[0]


train_test.to_pickle(os.getcwd()+'/../Data/'+'submission')
# Out:
#              Id    Visits   page           project      access       agent  \
# 0  bf4edcf969af  2.783192  !vote  en.wikipedia.org  all-access  all-agents
# 1  929ed2bf52b9  2.783192  !vote  en.wikipedia.org  all-access  all-agents
# 2  ff29d0f51d5c  2.783192  !vote  en.wikipedia.org  all-access  all-agents
# 3  e98873359be6  2.783192  !vote  en.wikipedia.org  all-access  all-agents
# 4  fa012434263a  2.783192  !vote  en.wikipedia.org  all-access  all-agents
#
#          date    1
# 0  2017-01-01  1.0
# 1  2017-01-02  1.0
# 2  2017-01-03  1.0
# 3  2017-01-04  1.0
# 4  2017-01-05  1.0
